# %%
from visualizations import *
import matplotlib.pyplot as plt
model_path = 'saved_models/flickr_100epochs.tar'

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Visualization

# %%
batch_size=10
flickr_processor = FlickrViz(batch_size=batch_size,parse_mode='phrase',
                            model_path=model_path, mode='test')
# Out:
# Loaded pretrained models

# %%
index = 0
element_dict = flickr_processor[index]
flickr_processor(save_flag=True, seg_flag=False, name='boy_girl_halloween')

# %% [markdown]
# ## Localization Quantitative Evaluation

# %%
flickr_processor_eval = FlickrViz(batch_size=10,parse_mode='phrase',
                            model_path=model_path, mode='test', eval_mode=True)
length_of_dataset = len(flickr_processor_eval.dataset)
# Out:
# Loaded pretrained models

# %%
score, score_list = flickr_processor_eval.loc_eval(length_of_dataset)
# Out:
#   0%|                                                                                             | 0/5000 [00:00<?, ?it/s]
# 0 ---> 0.6 0.6
#   2%|█▌                                                                               | 100/5000 [01:31<1:13:40,  1.11it/s]
# 100 ---> 0.6666666666666666 0.5653465346534653
#   4%|███▏                                                                             | 200/5000 [03:12<1:25:23,  1.07s/it]
# 200 ---> 0.5 0.5038142620232172
#   6%|████▊                                                                            | 300/5000 [04:53<1:12:51,  1.08it/s]
# 300 ---> 0.75 0.5299557032115172
#   8%|██████▍                                                                          | 400/5000 [06:34<1:20:07,  1.05s/it]
# 400 ---> 1.0 0.5081463009143807
#  10%|████████                                                                         | 500/5000 [08:12<1:10:31,  1.06it/s]
# 500 ---> 0.6666666666666666 0.5397870924817032
# ...

# %%
score
# Out:
# 0.51067

# %%
fig, ax = plt.figure(figsize=(100,30), facecolor="white")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-e5e6a4fb3abb> in <module>
# ----> 1 fig, ax = plt.figure(figsize=(100,30), facecolor="white")
#
# TypeError: cannot unpack non-iterable Figure object
